# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv('pagecounts-20190509-120000.txt', sep=' ', header=None, index_col=1, names=['lang', 'page', 'views', 'bytes'])

# %%
sorted1 = data1.sort_values('views', ascending = False)

# %%
#print(sorted1)

# %%
data2 = pd.read_csv('pagecounts-20190509-130000.txt', sep=' ', header=None, index_col=1, names=['lang', 'page', 'views', 'bytes'])

# %%
data2['data1views'] = data1['views']
#sorted2 = data2.sort_values('views', ascending = False)

# %%
#print(data1)
#print(sorted2)

# %%
plt.figure(figsize=(14, 8)) # change size to some sensible
plt.subplot(1,2,1) # subplots in 1 row, 2 columns, select the first
plt.plot(sorted1['views'].values)
plt.subplot(1,2,2)
plt.title('Daily Correlation')
plt.xlabel('Day 1 Views')
plt.ylabel('Day 2 Views')
plt.xscale('log')
plt.yscale('log')
plt.xlim(0.8,1000)
plt.ylim(0.8,1000)
plt.axis('tight')
plt.scatter(data2['data1views'],data2['views'])
