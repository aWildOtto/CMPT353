# %%
import numpy as np
import pandas as pd
import sys
import difflib

# %%
movie_list = "movie_list.txt"

# %%
#movie_ratings = "movie_ratings.csv"

# %%
movies = open(movie_list).readlines()

# %%
df = pd.DataFrame(movies, columns={'title'})

# %%
movies_series = df['title'].str.replace('\n','', regex=True)

# %%
movies_df = pd.DataFrame(movies_series, columns={'title'})

# %%
def match_title(title):
    match = difflib.get_close_matches(title, movies_df['title'], n=100, cutoff=0.6)
    return match

# %%
movie_ratings = pd.read_csv("movie_ratings.csv")

# %%
ratings_df = pd.DataFrame(movie_ratings, columns=['title', 'rating'])

# %%
matched_ratings = ratings_df['title'].apply(lambda title:match_title(title))

# %%
ratings_df['matched'] = matched_ratings

# %%
ratings_df['matched'] = ratings_df['matched'].astype(str)

# %%
ratings_df['matched'] = ratings_df['matched'].str.strip('[]"')

# %%
ratings_df['matched'] = ratings_df['matched'].str.strip("'")
ratings_df = ratings_df[ratings_df.matched != '']

# %%
ratings_df = ratings_df.drop('title',1)

# %%
final_df = pd.DataFrame()
final_df['title'] = ratings_df['matched']

# %%
final_df['rating'] = ratings_df['rating']

# %%
final_df = final_df.groupby(['title']).mean()

# %%
final_df
# Out:
#                                                       rating
# title
# 28 Days Later...                                    7.181818
# A Time to Kill                                      7.916667
# Anomalisa                                           7.500000
# Central Intelligence                                6.878049
# Dead Poets Society                                  8.333333
# Detachment                                          8.136364
# Dial M for Murder                                   8.125000
# Dog Day Afternoon                                   8.600000
# El cuerpo                                           8.444444
# Everest                                             7.046512
# Everest', 'Tower Heist                              8.000000
# Everybody Wants Some!!                              6.875000
# Garden State                                        8.666667
# God Bless America                                   7.500000
# Heaven Is for Real                                  6.125000
# Hitman: Agent 47                                    5.500000
# House at the End of the Street                      6.071429
# House at the End of the Street', 'The End of th...  5.714286
# I Spit on Your Grave 2                              6.230769
# Intouchables                                        8.931507
# Jûsan-nin no shikaku                                8.000000
# Love Actually                                       8.000000
# Macbeth                                             7.166667
# Madagascar 3: Europe's Most Wanted                  6.666667
# Maleficent                                          7.537500
# Maleficent', 'Detachment                            6.000000
# Maleficent', 'Macbeth                               7.909091
# Man on Fire                                         8.444444
# Maps to the Stars                                   5.692308
# Maps to the Stars', 'War of the Worlds              8.000000
# ...                                                      ...
# Mrs. Doubtfire                                      8.500000
# Much Ado About Nothing                              7.545455
# Neighbors 2: Sorority Rising                        5.352941
# Non-Stop                                            7.233010
# P.S. I Love You                                     6.500000
# Paul Blart: Mall Cop 2                              5.600000
# Pitch Perfect 2                                     7.266667
# Poltergeist                                         8.333333
# Poltergeist', 'Everest', 'Tower Heist               8.000000
# Poltergeist', 'Tower Heist                          8.000000
# Real Steel                                          8.200000
# Shaun the Sheep Movie                               7.214286
# Sightseers                                          6.666667
# Sunshine                                            7.500000
# Texas Chainsaw 3D                                   5.190476
# The End of the Tour                                 8.250000
# The End of the Tour', 'House at the End of the ...  6.000000
# The Life of David Gale                              8.400000
# To the Wonder                                       4.800000
# To the Wonder', 'War of the Worlds                  7.250000
# Tower Heist                                         5.333333
# Tower Heist', 'Poltergeist                          8.000000
# Tower Heist', 'Poltergeist', 'Everest               6.000000
# Tyler Perry's Temptation                            5.000000
# Vaiana                                              8.000000
# War of the Worlds                                   8.333333
# War of the Worlds', 'To the Wonder                  8.000000
# Welcome to Me                                       6.000000
# Why Him?                                            6.357143
# Wreck-It Ralph                                      7.828571
#
# [61 rows x 1 columns]

# %%
final_df['rating'] = final_df['rating'].round(2)

# %%
final_df
# Out:
#                                                     rating
# title
# 28 Days Later...                                      7.18
# A Time to Kill                                        7.92
# Anomalisa                                             7.50
# Central Intelligence                                  6.88
# Dead Poets Society                                    8.33
# Detachment                                            8.14
# Dial M for Murder                                     8.12
# Dog Day Afternoon                                     8.60
# El cuerpo                                             8.44
# Everest                                               7.05
# Everest', 'Tower Heist                                8.00
# Everybody Wants Some!!                                6.88
# Garden State                                          8.67
# God Bless America                                     7.50
# Heaven Is for Real                                    6.12
# Hitman: Agent 47                                      5.50
# House at the End of the Street                        6.07
# House at the End of the Street', 'The End of th...    5.71
# I Spit on Your Grave 2                                6.23
# Intouchables                                          8.93
# Jûsan-nin no shikaku                                  8.00
# Love Actually                                         8.00
# Macbeth                                               7.17
# Madagascar 3: Europe's Most Wanted                    6.67
# Maleficent                                            7.54
# Maleficent', 'Detachment                              6.00
# Maleficent', 'Macbeth                                 7.91
# Man on Fire                                           8.44
# Maps to the Stars                                     5.69
# Maps to the Stars', 'War of the Worlds                8.00
# ...                                                    ...
# Mrs. Doubtfire                                        8.50
# Much Ado About Nothing                                7.55
# Neighbors 2: Sorority Rising                          5.35
# Non-Stop                                              7.23
# P.S. I Love You                                       6.50
# Paul Blart: Mall Cop 2                                5.60
# Pitch Perfect 2                                       7.27
# Poltergeist                                           8.33
# Poltergeist', 'Everest', 'Tower Heist                 8.00
# Poltergeist', 'Tower Heist                            8.00
# Real Steel                                            8.20
# Shaun the Sheep Movie                                 7.21
# Sightseers                                            6.67
# Sunshine                                              7.50
# Texas Chainsaw 3D                                     5.19
# The End of the Tour                                   8.25
# The End of the Tour', 'House at the End of the ...    6.00
# The Life of David Gale                                8.40
# To the Wonder                                         4.80
# To the Wonder', 'War of the Worlds                    7.25
# Tower Heist                                           5.33
# Tower Heist', 'Poltergeist                            8.00
# Tower Heist', 'Poltergeist', 'Everest                 6.00
# Tyler Perry's Temptation                              5.00
# Vaiana                                                8.00
# War of the Worlds                                     8.33
# War of the Worlds', 'To the Wonder                    8.00
# Welcome to Me                                         6.00
# Why Him?                                              6.36
# Wreck-It Ralph                                        7.83
#
# [61 rows x 1 columns]
